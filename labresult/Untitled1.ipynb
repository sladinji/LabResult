# %%
import pstats
pstats.Stats

# %%
import pstats
p = pstats.Stats('profile.out')
#p.strip_dirs().sort_stats(-1).print_stats()
p.sort_stats('cumulative').print_stats()
# Out:
# Thu Nov 27 10:18:48 2014    profile.out
#
#          2600488 function calls (2543444 primitive calls) in 10.851 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     571/1    0.018    0.000   10.863   10.863 {built-in method exec}
#         1    0.000    0.000   10.863   10.863 ./bin/nosetests:3(<module>)
#         1    0.000    0.000   10.707   10.707 /home/dowst/projets/labresult/lib/python3.4/site-packages/nose/core.py:102(__init__)
#         1    0.000    0.000   10.706   10.706 /usr/lib/python3.4/unittest/main.py:58(__init__)
#         1    0.000    0.000   10.167   10.167 /home/dowst/projets/labresult/lib/python3.4/site-packages/nose/core.py:195(runTests)
#         1    0.000    0.000   10.166   10.166 /home/dowst/projets/labresult/lib/python3.4/site-packages/nose/core.py:46(run)
# ...
